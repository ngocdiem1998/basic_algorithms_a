# %% [markdown]
# <a href="https://colab.research.google.com/github/ngocdiem1998/basic_algorithms_a/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def vend():

    a = {'nomimono': 'お茶', 'nedan': 120, 'zaiko': 22}
    b = {'nomimono': 'ミルクティー', 'nedan': 150, 'zaiko': 15}
    c = {'nomimono': 'ラテコーヒー', 'nedan': 200, 'zaiko': 13}
    d = {'nomimono': 'ホット お茶', 'nedan': 120, 'zaiko': 15}
    e = {'nomimono': 'ホット ミルクティー', 'nedan': 150, 'zaiko': 20}
    jidouhanbaiki = [a, b, c, d, e]
    okane = 0

    print('いらっしゃませ。。。\nご来店ありがとうございます。')

    
    def show(jidouhanbaiki):
        print('\nメニューです。\n')

        for nomimono in jidouhanbaiki:      
            if nomimono.get('zaiko') == 0:
                jidouhanbaiki.remove(nomimono)
        for nomimono in jidouhanbaiki:
            print(nomimono.get('nomimono'), nomimono.get('nedan'))

        print('メニューの中に　一つお選びください\n')

   
    while True:
        show(jidouhanbaiki)
        erabi = input('ご注文は: ')
        for nomimono in jidouhanbaiki:
            if erabi == nomimono.get('nomimono'):
                erabi = nomimono               
                nedan = erabi.get('nedan')
                while okane < nedan:
                    okane = float(input(str(nedan - okane) + '¥ 不足です。'))  
                
                else:
                    print('はい。'+erabi.get('nomimono')+' でございます')
                    erabi['zaiko'] -= 1
                    okane -= nedan
                    print('お釣りは： ' + str(okane)+'¥　です')
                    a = input('まだ お続けますか？ (y/n): ')
                    if a == 'n':
                        if okane != 0:
                            print('はい。'+str(okane) + ' ¥ お返します。')
                            okane = 0
                            print('ご利用ありがとうございます!\nまた　ご利用くださいませ')
                            break                        
                        else:
                          print('ご利用ありがとうございます!\n')
                          break                        
                    else:
                        continue
                


vend()
# Out:
# いらっしゃませ。。。
# ご来店ありがとうございます。
#
# メニューです。
#
# お茶 120
# ミルクティー 150
# ラテコーヒー 200
# ホット お茶 120
# ホット ミルクティー 150
# メニューの中に　一つお選びください
#
# ご注文は: お茶
# 120¥ 不足です。500
# はい。お茶 でございます
# お釣りは： 380.0¥　です
# まだ お続けますか？ (y/n): n
# はい。380.0 ¥ お返します。
# ご利用ありがとうございます!
# また　ご利用くださいませ
#
# メニューです。
#
# お茶 120
# ミルクティー 150
# ラテコーヒー 200
# ホット お茶 120
# ホット ミルクティー 150
# メニューの中に　一つお選びください
#
# ご注文は: ラテコーヒー
# 200¥ 不足です。300
# はい。ラテコーヒー でございます
# お釣りは： 100.0¥　です
# まだ お続けますか？ (y/n): n
# はい。100.0 ¥ お返します。
# ご利用ありがとうございます!
# また　ご利用くださいませ
#
# メニューです。
#
# お茶 120
# ミルクティー 150
# ラテコーヒー 200
# ホット お茶 120
# ホット ミルクティー 150
# メニューの中に　一つお選びください
#
# ご注文は: ホット ミルクティー
# 150¥ 不足です。500
# はい。ホット ミルクティー でございます
# お釣りは： 350.0¥　です
# まだ お続けますか？ (y/n): y
#
# メニューです。
#
# お茶 120
# ミルクティー 150
# ラテコーヒー 200
# ホット お茶 120
# ホット ミルクティー 150
# メニューの中に　一つお選びください
#
# ご注文は: ホット お茶
# はい。ホット お茶 でございます
# お釣りは： 230.0¥　です
# まだ お続けますか？ (y/n): n
# はい。230.0 ¥ お返します。
# ご利用ありがとうございます!
# また　ご利用くださいませ
#
# メニューです。
#
# お茶 120
# ミルクティー 150
# ラテコーヒー 200
# ホット お茶 120
# ホット ミルクティー 150
# メニューの中に　一つお選びください
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-190d61eab714> in <module>()
#      54
#      55
# ---> 56 vend()
#
# <ipython-input-23-190d61eab714> in vend()
#      26     while True:
#      27         show(jidouhanbaiki)
# ---> 28         erabi = input('ご注文は: ')
#      29         for nomimono in jidouhanbaiki:
#      30             if erabi == nomimono.get('nomimono'):
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
